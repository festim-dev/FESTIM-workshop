# %% [markdown]
# # Fusion fuel cycle modeling #
#
# FESTIM can be used to model fusion fuel cycle components.
#
# * Fuel cycle components
# * System level modeling?

# %%
from IPython.display import HTML

with open("test.svg") as f:
    svg = f.read()

HTML(svg)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <svg id="Layer_1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" version="1.1" viewBox="0 0 595.28 841.89">
#   <!-- Generator: Adobe Illustrator 29.8.2, SVG Export Plug-In . SVG Version: 2.1.1 Build 3)  -->
#   <defs>
#     <style>
#       .st0, .st1, .st2, .st3 {
#         isolation: isolate;
#       }
#
#       .st1 {
#         fill: #231f20;
#       }
#
#       .st1, .st2, .st3 {
#         font-family: ArialMT, Arial;
#         font-size: 10px;
#       }
#
#       .st4 {
#         stroke: #082222;
#       }
#
#       .st4, .st5, .st6, .st7 {
#         stroke-miterlimit: 10;
#       }
#
#       .st4, .st7 {
#         fill: #39b54a;
#       }
#
#       .st5 {
#         fill: none;
#       }
#
#       .st5, .st7 {
#         stroke: #231f20;
#         stroke-linecap: round;
#       }
#
#       .st6 {
#         fill: #f7941d;
#         stroke: #1a4848;
#       }
#
#       .st2 {
#         fill: #082222;
#       }
#
#       .st3 {
#         fill: #1a4848;
#       }
#     </style>
#   </defs>
#   <a xlink:href="https://festim-workshop.readthedocs.io/en/festim2/intro.html">
#     <g>
#       <rect class="st6" x="184.99" y="386.55" width="225.29" height="68.78"/>
#       <a xlink:href="https://festim-workshop.readthedocs.io/en/festim2/intro.html">
#         <g class="st0">
#           <text class="st3" transform="translate(281.76 424.5)"><tspan x="0" y="0">Reactor</tspan></text>
#         </g>
#       </a>
#     </g>
#   </a>
#   <a xlink:href="https://github.com/kaelyndunnell/Fusion-TES-Modeling">
#     <g>
#       <rect class="st4" x="273.5" y="542.94" width="48.28" height="29.89"/>
#       <g class="st0">
#         <text class="st1" transform="translate(290.23 561.43)"><tspan x="0" y="0">TES</tspan></text>
#       </g>
#     </g>
#   </a>
#   <a xlink:href="https://iopscience.iop.org/article/10.1088/1741-4326/acf3fc">
#     <g>
#       <rect class="st4" x="273.5" y="484.2" width="48.28" height="29.89"/>
#       <g class="st0">
#         <text class="st2" transform="translate(282.06 502.69)"><tspan x="0" y="0">Blanket</tspan></text>
#       </g>
#     </g>
#   </a>
#   <path class="st7" d="M300.95,483.87"/>
#   <path class="st7" d="M299.6,455.56"/>
#   <line class="st5" x1="297.64" y1="512.71" x2="297.64" y2="545.33"/>
#   <line class="st5" x1="297.64" y1="454.08" x2="297.64" y2="486.7"/>
# </svg>
